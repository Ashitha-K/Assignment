# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashitha-K/Assignment/blob/main/virtual_competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(data,index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# 2. Display a summary of the basic information about this DataFrame and its data (hint: there is a single method that can be called on the DataFrame).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# 4. Display the 'animal' and 'age' columns from the DataFrame df

# %%
print(df['animal'])
# Out:
# a      cat
# b      cat
# c    snake
# d      dog
# e      dog
# f      cat
# g    snake
# h      cat
# i      dog
# j      dog
# Name: animal, dtype: object

# %%
print(df['age'])
# Out:
# a    2.5
# b    3.0
# c    0.5
# d    NaN
# e    5.0
# f    2.0
# g    4.5
# h    NaN
# i    7.0
# j    3.0
# Name: age, dtype: float64

# %% [markdown]
# 5. Display the data in rows [3, 4, 8] and in columns `['animal', 'age']'

# %%
new_data = df.loc[df.index[[3, 4, 8]], ['animal', 'age']]
print(new_data)
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# 6.Select only the rows where the number of visits is greater than 3.

# %%
visits=df[df['visits'] >3]
print(visits)
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
age_null=df[df['age'].isna()]
print(age_null)
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.
#
# *   List item
# *   List item

# %%
data1=df[(df['animal'] == 'cat') & (df['age'] < 3)]
print(data1)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
output = df[(df['age'] >= 2) & (df['age'] <= 4)]
print(output)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# 10. Change the age in row 'f' to 1.5.

# %%
df.loc['f','age'] =1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5     1.0      yes
# b    cat  3.0     3.0      yes
# c  snake  0.5     2.0       no
# d    dog  NaN     3.0      yes
# e    dog  5.0     2.0       no
# f    cat  1.5     3.0       no
# g  snake  4.5     1.0       no
# h    cat  NaN     1.0      yes
# i    dog  7.0     2.0       no
# j    dog  3.0     1.0       no
# 5    NaN  1.5     NaN      NaN

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
total_visits=df['visits'].sum()
print(total_visits)
# Out:
# 19.0

# %% [markdown]
# 12.Calculate the mean age for each different animal in df.

# %%
mean_age = df.groupby('animal')['age'].mean()
mean_age
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# 13. Append a new row 'k' to df with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
new_row = {'animal': 'monkey', 'age': 0.5, 'visits': 1, 'priority': 'yes'}
df= pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
print(df)
# Out:
#     animal  age  visits priority
# 0      cat  2.5       1      yes
# 1      cat  3.0       3      yes
# 2    snake  0.5       2       no
# 3      dog  NaN       3      yes
# 4      dog  5.0       2       no
# 5      cat  2.0       3       no
# 6    snake  4.5       1       no
# 7      cat  NaN       1      yes
# 8      dog  7.0       2       no
# 9      dog  3.0       1       no
# 10  monkey  0.5       1      yes

# %%
df = df.drop(index=10)
print(df)
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no
# 3    dog  NaN       3      yes
# 4    dog  5.0       2       no
# 5    cat  2.0       3       no
# 6  snake  4.5       1       no
# 7    cat  NaN       1      yes
# 8    dog  7.0       2       no
# 9    dog  3.0       1       no

# %% [markdown]
# 14.Count the number of each type of animal in df.

# %%
animal_count=df['animal'].value_counts()
print(animal_count)
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %% [markdown]
# 15.Sort df first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order (so row i should be first, and row d should be last).

# %%
df_sorted = df.sort_values(by=['age', 'visits'], ascending=[False, True])

print("Sorted DataFrame:")
print(df_sorted)
# Out:
# Sorted DataFrame:
#   animal  age  visits priority
# i    dog  7.0     2.0       no
# e    dog  5.0     2.0       no
# g  snake  4.5     1.0       no
# j    dog  3.0     1.0       no
# b    cat  3.0     3.0      yes
# a    cat  2.5     1.0      yes
# f    cat  1.5     3.0       no
# 5    NaN  1.5     NaN      NaN
# c  snake  0.5     2.0       no
# h    cat  NaN     1.0      yes
# d    dog  NaN     3.0      yes

# %% [markdown]
# 16. The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be True and 'no' should be False.

# %%
df['priority'] = df['priority'].replace({'yes': True, 'no': False})
df['priority']
# Out:
# a     True
# b     True
# c    False
# d     True
# e    False
# f    False
# g    False
# h     True
# i    False
# j    False
# 5      NaN
# Name: priority, dtype: object

# %% [markdown]
# *17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
#df['column_name'] = df['column_name'].replace('A', 'X')
df['animal']=df['animal'].replace('snake','python')
print(df['animal'])
# Out:
# a       cat
# b       cat
# c    python
# d       dog
# e       dog
# f       cat
# g    python
# h       cat
# i       dog
# j       dog
# 5       NaN
# Name: animal, dtype: object

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
flight_data=pd.read_csv("/content/ny-flights (2).csv")
flight_data
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset
#
# *   List item
# *   List item

# %%
flight_data['airline_id'].value_counts()
# Out:
# airline_id
# 20409    4902
# 19790    3803
# 20398    2434
# 19805    2427
# 20366    2080
# 19393    1917
# 20355    1568
# 19977    1106
# 21171     301
# 20437     206
# 20436      33
# 19690      29
# 20304      11
# Name: count, dtype: int64

# %% [markdown]
# 20. Draw a plot between dep_delay and arr_delay

# %%
import matplotlib.pyplot as plt
plt.scatter(flight_data['dep_delay'],flight_data['arr_delay'], alpha=1, s=20,color='green')
plt.title('Departure Delay vs Arrival Delay')
plt.xlabel('Departure Delay')
plt.ylabel('Arrival Delay')
plt.show()
